# %% [markdown]
# # Two-Level: Weak CW through Some Atoms with Decay
#
# Time taken to solve this problem on a 2013 MacBook Pro:
# **?**.

# %% [markdown]
# ## Define the Problem

# %%
mb_solve_json = """
{
  "ob_atom": {
    "decays": [
      {
        "channels": [[0, 1]],
        "rate": 1.0
      }
    ],
    "energies": [],
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "detuning": 0.0,
        "detuning_positive": true,
        "label": "probe",
        "rabi_freq": 1.0e-3,
        "rabi_freq_t_args": {
          "ampl_1": 1.0,
          "on_1": 0.0,
          "off_1": 25.0,
          "fwhm_1": 1.0
        },
        "rabi_freq_t_func": "ramp_onoff_1"
      }
    ],
    "num_states": 2
  },
  "t_min": -5.0,
  "t_max": 30.0,
  "t_steps": 350,
  "z_min": -0.2,
  "z_max": 1.2,
  "z_steps": 100,
  "z_steps_inner": 2,
  "num_density_z_func": "square_1",
  "num_density_z_args": {
    "on_1": 0.0,
    "off_1": 1.0,
    "ampl_1": 1.0
  },
  "interaction_strengths": [
    10.0
  ],
  "velocity_classes": {
    "thermal_delta_min": -0.0,
    "thermal_delta_max": 0.0,
    "thermal_delta_steps": 0,
    "thermal_delta_inner_min": 0.0,
    "thermal_delta_inner_max": 0.0,
    "thermal_delta_inner_steps": 0,
    "thermal_width": 1.0
  },
  "method": "mesolve",
  "opts": {},
  "savefile": "qu/mb-solve-two-weak-cw-some-atoms-decay-long"
}
"""

# %%
from maxwellbloch import mb_solve
mb_solve_00 = mb_solve.MBSolve().from_json_str(mb_solve_json)

# %% [markdown]
# ## Solve the Problem

# %%
# %time Omegas_zt, states_zt = mb_solve_00.mbsolve(recalc=True)
# Out:
# 10.0%. Run time:  18.84s. Est. time left: 00:00:02:49
# 20.0%. Run time:  37.86s. Est. time left: 00:00:02:31
# 30.0%. Run time:  62.07s. Est. time left: 00:00:02:24
# 40.0%. Run time:  79.81s. Est. time left: 00:00:01:59
# 50.0%. Run time:  93.95s. Est. time left: 00:00:01:33
# 60.0%. Run time: 114.01s. Est. time left: 00:00:01:16
# 70.0%. Run time: 129.36s. Est. time left: 00:00:00:55
# 80.0%. Run time: 143.16s. Est. time left: 00:00:00:35
# 90.0%. Run time: 155.95s. Est. time left: 00:00:00:17
# 100.0%. Run time: 168.25s. Est. time left: 00:00:00:00
# Total run time: 169.57s
# Saving MBSolve to qu/mb-solve-two-weak-cw-some-atoms-decay-long .qu
# CPU times: user 2min 38s, sys: 1.63 s, total: 2min 39s
# Wall time: 2min 50s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import numpy as np

# %% [markdown]
# ## Field Output

# %%
fig = plt.figure(1, figsize=(16, 6))
ax = fig.add_subplot(111)
cmap_range = np.linspace(0.0, 1.0e-3, 11)
cf = ax.contourf(mb_solve_00.tlist, mb_solve_00.zlist, 
                 np.abs(mb_solve_00.Omegas_zt[0]/(2*np.pi)), 
                 cmap_range, cmap=plt.cm.Blues)
ax.set_title('Rabi Frequency ($\Gamma / 2\pi $)')
ax.set_xlabel('Time ($1/\Gamma$)')
ax.set_ylabel('Distance ($L$)')
for y in [0.0, 1.0]:
    ax.axhline(y, c='grey', lw=1.0, ls='dotted')
plt.colorbar(cf)
plt.savefig('images/mb-solve-two-weak-cw-some-atoms-decay-long.png')

# %%
y_min = 0.0
y_max = 1.0e-3
speed_of_light = 0.25

fig = plt.figure(1, figsize=(16, 6))
ax = fig.add_subplot(111)
cf = ax.contourf(mb_solve_00.tlist_fixed_frame(speed_of_light), 
                 mb_solve_00.zlist, 
                 np.abs(mb_solve_00.Omegas_fixed_frame(0, speed_of_light, interp_kind='quintic')/(2*np.pi)), 
                 cmap=plt.cm.Blues)

ax.set_title('Rabi Frequency ($\Gamma / 2\pi $)')
ax.set_xlabel('Fixed Time ($1/\Gamma$)')
ax.set_ylabel('Distance ($L$)')
for y in [0.0, 1.0]:
    ax.axhline(y, c='grey', lw=1.0, ls='dotted')
plt.colorbar(cf)
