# %% [markdown]
# # Two-Level: Sech Pulse 4π — Pulse Breakup
#
# Time taken to solve this problem on a 2013 MacBook Pro:
# **1min 17s**

# %% [markdown]
# ## Define the Problem
#
# First we need to define a sech pulse with the area we want. We'll fix the width of the pulse and the area to find the right amplitude.
#
# The full-width at half maximum (FWHM) $t_s$ of the sech pulse is related to the FWHM of a Gaussian by a factor of $1/2.6339157938$. (See §3.2.2 of my [PhD thesis](https://github.com/tommyogden/phd-thesis)).
#
# We then obtain the amplitude $a$ we need from
#
# $$
# a = \frac{n}{2 \pi ~ t_s}
# $$

# %%
import numpy as np

sech_fwhm_conv = 1./2.6339157938
t_width = 1.0*sech_fwhm_conv # [τ]

print('t_width', t_width)

n = 4.0 # For a pulse area of nπ    
ampl = n/t_width/(2*np.pi) # Pulse amplitude [2π Γ]

print('ampl', ampl)
# Out:
# t_width 0.3796628587572578
# ampl 1.6768028730843334

# %%
mb_solve_json = """
{
  "atom": {
    "decays": [
      {
        "channels": [[0, 1]],
        "rate": 0.0
      }
    ],
    "energies": [],
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "detuning": 0.0,
        "detuning_positive": true,
        "label": "probe",
        "rabi_freq": 1.6768028730843334,
        "rabi_freq_t_args": {
          "ampl": 1.0,
          "centre": 0.0,
          "width": 0.3796628587572578
        },
        "rabi_freq_t_func": "sech"
      }
    ],
    "num_states": 2
  },
  "t_min": -2.0,
  "t_max": 10.0,
  "t_steps": 240,
  "z_min": -0.5,
  "z_max": 1.5,
  "z_steps": 200,
  "z_steps_inner": 1,
  "num_density_z_func": "square",
  "num_density_z_args": {
    "on": 0.0,
    "off": 1.0,
    "ampl": 1.0
  },
  "interaction_strengths": [
    10.0
  ],
  "velocity_classes": {},
  "method": "mesolve",
  "opts": {},
  "savefile": "qu/mb-solve-two-sech-4pi"
}
"""

# %%
from maxwellbloch import mb_solve
mb_solve_00 = mb_solve.MBSolve().from_json_str(mb_solve_json)

# %% [markdown]
# We'll just check that the pulse area is what we want.

# %%
print('The input pulse area is {0}'.format(np.trapz(mb_solve_00.Omegas_zt[0,0,:].real, 
                                                    mb_solve_00.tlist)/np.pi))
# Out:
# The input pulse area is 3.9868546216125154

# %%
# %time Omegas_zt, states_zt = mb_solve_00.mbsolve(recalc=False)
# Out:
# Loaded tuple object.
# CPU times: user 7.6 ms, sys: 10.2 ms, total: 17.8 ms
# Wall time: 21.8 ms

# %% [markdown]
# ## Plot Output

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import numpy as np

sns.set_style('darkgrid')
fig = plt.figure(1, figsize=(16, 6))
ax = fig.add_subplot(111)
cmap_range = np.linspace(0.0, 3.0, 11)
cf = ax.contourf(mb_solve_00.tlist, mb_solve_00.zlist, 
                 np.abs(mb_solve_00.Omegas_zt[0]/(2*np.pi)), 
                 cmap_range, cmap=plt.cm.Blues)
ax.set_title('Rabi Frequency ($\Gamma / 2\pi $)')
ax.set_xlabel('Time ($1/\Gamma$)')
ax.set_ylabel('Distance ($L$)')
for y in [0.0, 1.0]:
    ax.axhline(y, c='grey', lw=1.0, ls='dotted')
plt.colorbar(cf)
plt.savefig('images/mb-solve-two-sech-4pi.png')

# %%
fig, ax = plt.subplots(figsize=(16, 5))
ax.plot(mb_solve_00.zlist, mb_solve_00.fields_area()[0]/np.pi)
ax.set_ylim([0.0, 8.0])
ax.set_xlabel('Distance ($L$)')
ax.set_ylabel('Pulse Area ($\pi$)')
# Out:
# Text(0,0.5,'Pulse Area ($\\pi$)')

# %% [markdown]
# ## Analysis
#
# The $4 \pi$ sech pulse breaks up into two $2 \pi$ pulses, which travel at a speed according to their width.

# %% [markdown]
# ## Movie

# %%
C = 0.1 # speed of light
Y_MIN = 0.0 # Y-axis min
Y_MAX = 4.0 # y-axis max
ZOOM = 2 # level of linear interpolation
FPS = 60 # frames per second
ATOMS_ALPHA = 0.2 # Atom indicator transparency

# %%
FNAME = "images/mb-solve-two-sech-4pi"
FNAME_JSON = FNAME + '.json'
with open(FNAME_JSON, "w") as f:
    f.write(mb_solve_json)

# %%
# !make-mp4-fixed-frame.py -f $FNAME_JSON -c $C --fps $FPS --y-min $Y_MIN --y-max $Y_MAX \
    --zoom $ZOOM --atoms-alpha $ATOMS_ALPHA #--peak-line --c-line
# Out:
# Namespace(atoms_alpha='0.2', c_line=False, file='images/mb-solve-two-sech-4pi.json', fps='60', peak_line=False, save_path='./', speed_of_light='0.1', y_max='4.0', y_min='0.0', zoom='2')
# Loaded tuple object.
# Saving MP4
# ./images/mb-solve-two-sech-4pi.mp4
# Figure(1200x400)

# %%
FNAME_MP4 = FNAME + '.mp4'
# !make-gif-ffmpeg.sh -f $FNAME_MP4 --in-fps $FPS
# Out:
# Converting images/mb-solve-two-sech-4pi.mp4 to gif format
# Input Scale: 900
# Input FPS: 60
# Output Scale: 900
# Output FPS: 30
# /Users/tommy/.miniconda3/envs/mb-0.4.0/bin/make-gif-ffmpeg.sh: line 59: Y: command not found
# ffmpeg version 3.2.4 Copyright (c) 2000-2017 the FFmpeg developers
#   built with Apple LLVM version 8.0.0 (clang-800.0.42.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/3.2.4 --enable-shared --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-libmp3lame --enable-libx264 --enable-libxvid --enable-opencl --disable-lzma --enable-vda
#   libavutil      55. 34.101 / 55. 34.101
#   libavcodec     57. 64.101 / 57. 64.101
#   libavformat    57. 56.101 / 57. 56.101
#   libavdevice    57.  1.100 / 57.  1.100
#   libavfilter     6. 65.100 /  6. 65.100
#   libavresample   3.  1.  0 /  3.  1.  0
#   libswscale      4.  2.100 /  4.  2.100
#   libswresample   2.  3.100 /  2.  3.100
#   libpostproc    54.  1.100 / 54.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'images/mb-solve-two-sech-4pi.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     artist          : Me
#     encoder         : Lavf57.56.101
#   Duration: 00:00:08.03, start: 0.000000, bitrate: 857 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1200x400, 851 kb/s, 60 fps, 60 tbr, 15360 tbn, 120 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Output #0, image2, to 'palette.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     artist          : Me
#     encoder         : Lavf57.56.101
#     Stream #0:0(und): Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 60 fps, 60 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.64.101 png
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [Parsed_palettegen_2 @ 0x7f81ff400860] 255(+1) colors generated out of 73578 colors; ratio=0.003466
# [Parsed_palettegen_2 @ 0x7f81ff400860] Dupped color: FFFEFCFE
#     Last message repeated 1 timesimes
# frame=    1 fps=0.6 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0101x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Outputting to .gif
# ffmpeg version 3.2.4 Copyright (c) 2000-2017 the FFmpeg developers
#   built with Apple LLVM version 8.0.0 (clang-800.0.42.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/3.2.4 --enable-shared --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-libmp3lame --enable-libx264 --enable-libxvid --enable-opencl --disable-lzma --enable-vda
#   libavutil      55. 34.101 / 55. 34.101
#   libavcodec     57. 64.101 / 57. 64.101
#   libavformat    57. 56.101 / 57. 56.101
#   libavdevice    57.  1.100 / 57.  1.100
#   libavfilter     6. 65.100 /  6. 65.100
#   libavresample   3.  1.  0 /  3.  1.  0
#   libswscale      4.  2.100 /  4.  2.100
#   libswresample   2.  3.100 /  2.  3.100
#   libpostproc    54.  1.100 / 54.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'images/mb-solve-two-sech-4pi.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     artist          : Me
#     encoder         : Lavf57.56.101
#   Duration: 00:00:08.03, start: 0.000000, bitrate: 857 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1200x400, 851 kb/s, 60 fps, 60 tbr, 15360 tbn, 120 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #1, png_pipe, from 'palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Output #0, gif, to '.gif':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     artist          : Me
#     encoder         : Lavf57.56.101
#     Stream #0:0: Video: gif, pal8, 900x300, q=2-31, 200 kb/s, 30 fps, 100 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc57.64.101 gif
# Stream mapping:
#   Stream #0:0 (h264) -> fps
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# frame=  242 fps= 60 q=-0.0 Lsize=    1372kB time=00:00:08.04 bitrate=1398.3kbits/s speed=   2x
# video:1370kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.195143%

# %%
from IPython.display import Image
Image(url=FNAME_MP4 +'.gif', format='gif')
# Out:
# <img src="images/mb-solve-two-sech-4pi.mp4.gif"/>
